# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tip=sns.load_dataset('tips')
titanic=sns.load_dataset('titanic')
iris=sns.load_dataset('iris')

# %%
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# In seaborn the graph plotted is more detailed by default we dont need to give lables explicit
# In seaborn the the scatter plot can be plotted using diffrent fields from dataset to get better visualization as in below graph:
# the x-axis has the tipgiven
# the y-axis has the total bill
# the color or hue is set on days like on diffrent day diffrent color marker is used
# the size of marker is set on the size attribute from the dataframe, the size in the dataframe represent the size of meal so depending on the size of meal the size of marker is plot

# %%
sns.scatterplot(x='tip',y='total_bill',data=tip,hue='day',size='size',palette='YlGnBu')
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %% [markdown]
# In histogram we get the labels from sns
# the sns histplot provides the parameter kde i.e  kernel density estimation

# %%
sns.histplot(tip['tip'],kde=True,bins=20)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.displot(tip['tip'],kde=True,bins=20)    #distribution plot

# %%
sns.barplot(x='sex',y='tip',data=tip,hue='sex')
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.boxplot(x='day',y='total_bill',data=tip,hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x='day',y='tip',data=tip,hue='sex',dodge=True)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.jointplot(x='tip',y='total_bill',data=tip,kind='hex',cmap='YlGnBu')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
#pair plot
sns.pairplot('Preferred Foot,hue='pclass')

# %%
sns.pairplot(tip,hue='sex')

# %%
tip.select_dtypes(['number']).corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tip.select_dtypes(['number']).corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.heatmap(titanic.select_dtypes(['number']).corr(),annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.clustermap(iris.drop('species',axis=1))

# %%
df_glue=sns.load_dataset('glue')

# %%
df_glue
# Out:
#           Model  Year      Encoder  Task  Score
# 0         ERNIE  2019  Transformer  CoLA   75.5
# 1            T5  2019  Transformer  CoLA   71.6
# 2       RoBERTa  2019  Transformer  CoLA   67.8
# 3          BERT  2018  Transformer  CoLA   60.5
# 4   BiLSTM+ELMo  2018         LSTM  CoLA   32.1
# ..          ...   ...          ...   ...    ...
# 59         BERT  2018  Transformer   RTE   70.1
# 60  BiLSTM+ELMo  2018         LSTM   RTE   57.4
# 61  BiLSTM+CoVe  2017         LSTM   RTE   52.7
# 62  BiLSTM+Attn  2017         LSTM   RTE   58.4
# 63       BiLSTM  2017         LSTM   RTE   57.4
#
# [64 rows x 5 columns]

# %%
glue=df_glue.pivot(index="Model", columns="Task", values="Score")

# %%
glue
# Out:
# Task         CoLA  MNLI  MRPC  QNLI   QQP   RTE  SST-2  STS-B
# Model
# BERT         60.5  86.7  89.3  92.7  72.1  70.1   94.9   87.6
# BiLSTM       11.6  65.6  81.8  74.6  62.5  57.4   82.8   70.3
# BiLSTM+Attn  18.6  67.6  83.9  74.3  60.1  58.4   83.0   72.8
# BiLSTM+CoVe  18.5  65.4  78.7  70.8  60.6  52.7   81.9   64.4
# BiLSTM+ELMo  32.1  67.2  84.7  75.5  61.1  57.4   89.3   70.3
# ERNIE        75.5  92.3  93.9  97.3  75.2  92.6   97.8   93.0
# RoBERTa      67.8  90.8  92.3  95.4  74.3  88.2   96.7   92.2
# T5           71.6  92.2  92.8  96.9  75.1  92.8   97.5   93.1

# %%
sns.heatmap(glue,annot=True)
# Out:
# <Axes: xlabel='Task', ylabel='Model'>

# %%
# Import libraries
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
 
 
# Creating dataset
x = np.outer(np.linspace(-3, 3, 32), np.ones(32))
y = x.copy().T # transpose
z = (np.sin(x **2) + np.cos(y **2) )
 
# Creating figure
fig = plt.figure(figsize =(14, 9))
ax = plt.axes(projection ='3d')
 
# Creating plot
ax.plot_surface(x, y, z)
 
# show plot
plt.show()

# %%
z
# Out:
# array([[-0.49901178,  0.38993128,  1.26772341, ...,  1.26772341,
#          0.38993128, -0.49901178],
#        [ 0.08862357,  0.97756663,  1.85535876, ...,  1.85535876,
#          0.97756663,  0.08862357],
#        [-0.39350085,  0.49544221,  1.37323434, ...,  1.37323434,
#          0.49544221, -0.39350085],
#        ...,
#        [-0.39350085,  0.49544221,  1.37323434, ...,  1.37323434,
#          0.49544221, -0.39350085],
#        [ 0.08862357,  0.97756663,  1.85535876, ...,  1.85535876,
#          0.97756663,  0.08862357],
#        [-0.49901178,  0.38993128,  1.26772341, ...,  1.26772341,
#          0.38993128, -0.49901178]])

# %%
z.shape
# Out:
# (32, 32)

# %%
x.shape
# Out:
# (32, 32)

# %%
y.shape
# Out:
# (32, 32)

# %%
x
# Out:
# array([[-3.        , -3.        , -3.        , ..., -3.        ,
#         -3.        , -3.        ],
#        [-2.80645161, -2.80645161, -2.80645161, ..., -2.80645161,
#         -2.80645161, -2.80645161],
#        [-2.61290323, -2.61290323, -2.61290323, ..., -2.61290323,
#         -2.61290323, -2.61290323],
#        ...,
#        [ 2.61290323,  2.61290323,  2.61290323, ...,  2.61290323,
#          2.61290323,  2.61290323],
#        [ 2.80645161,  2.80645161,  2.80645161, ...,  2.80645161,
#          2.80645161,  2.80645161],
#        [ 3.        ,  3.        ,  3.        , ...,  3.        ,
#          3.        ,  3.        ]])

# %%
y
# Out:
# array([[-3.        , -2.80645161, -2.61290323, ...,  2.61290323,
#          2.80645161,  3.        ],
#        [-3.        , -2.80645161, -2.61290323, ...,  2.61290323,
#          2.80645161,  3.        ],
#        [-3.        , -2.80645161, -2.61290323, ...,  2.61290323,
#          2.80645161,  3.        ],
#        ...,
#        [-3.        , -2.80645161, -2.61290323, ...,  2.61290323,
#          2.80645161,  3.        ],
#        [-3.        , -2.80645161, -2.61290323, ...,  2.61290323,
#          2.80645161,  3.        ],
#        [-3.        , -2.80645161, -2.61290323, ...,  2.61290323,
#          2.80645161,  3.        ]])

# %%
tip_column = tip['tip'].values.reshape(-1, 1)
total_bill_column = tip['total_bill'].values.reshape(-1, 1)
